# %%
#Q1. What is Abstraction in OOps? Explain with an example.
abstarction means we are not defining the body of the function or variables but giving access to other class to define them as per their goal.
import abc
class test:
    @abc.abstractmethod
    def a(self):
        pass
d=test()
class test1(test):
    def a(self):
        print('hii')
s=test1()
s.a()
class test2(test):
    def a(self):
        print('hii how r u')
f=test2()
f.a()
#Q2. Differentiate between Abstraction and Encapsulation. Explain with an example.
abstarction means we are not defining the body of the function or variables but giving access to other class to define them as per their goal.
encapsulating means binding the class attributes and functions within the object  and based  on access we can use them iff made private then we  cant acccess outside the class but can acccess in within class function.

#example encapsulation:
bank account
class bank:
    def __init__(self,balance):
        self.__balance=balance
    def deposit(self,amount):
        self.__balance+=amount
    def withdraw(self,amount):
        if self.__balance<amount:
            return False
        else:
            self.__balance-=amount
            return True
    def get(self):
        return self.__balance
d=bank(2000)
d.deposit(200)
print(d.withdraw(4000))
d.withdraw(1000)
print(d.get())

#abstarction:
import abc
class test:
    @abc.abstractmethod
    def a(self):
        pass
d=test()
class test1(test):
    def a(self):
        print('hii')
s=test1()
s.a()
class test2(test):
    def a(self):
        print('hii how r u')
f=test2()
f.a()
#Q3. What is abc module in python? Why is it used?
with this module if we import them in the program and used as a decorator for a class function by assigning description as abstract method we are able to define th body for that function in the child class .

#Q4. How can we achieve data abstraction?
import abc
class a:
    @abc.abstractmethod
    def b(self):
        pass
    @abc.abstractmethod
    def c(self):
        pass
class f(a):
    def b(self):
        return self.p+self.q
    def c(self):
        return self.q*self.p
    def __init__(self,p,q):
        self.p=p
        self.q=q
d=f(2,3)
print(d.b(),d.c())
#Q5. Can we create an instance of an abstract class? Explain your answer.
yes because this is simillar to normal class but the difference lies is only in the definition if it is provided or not
